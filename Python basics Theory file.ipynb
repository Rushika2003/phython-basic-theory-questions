# %% [raw]
# Q.1 What is python and why it is popular ?
# ANS: Python is a set of rules and symbols that define the process of writing computer program.
#      It is very popular due to its versatility, simplicity and good ecosystem of its liabrary.
#
# Q.2 what is an interpreter in python ?
# ANS: In python, an interpreter is a program that reads and executes a python code unlike compiled languages that translate code in machine language           ahead of time.
#
# Q.3 What are pre defined keywords in python ?
# ANS: Following are the keywords in python -
#       false, true, and, as, assert, pass, while, break, class, continue, def, del, elif, with, else, except, finally, for, form, lobal, return, yeild,         import, in ,is, lamda, nonlocal, not, or, try.
#
# Q.4 Can keywords be used as variable names ?
# ANS: No, you cannot use keywords as variable name. If we use keywords as variable name it will show syntex error.
#
# Q.5 What is mutability in python ?
# ANS: Mutability refers to whether the object can be changed after its created.
#
# Q.6 Why are lists mutable and tuples immutable ?
# ANS: Lists are designed to be flexible and dynamic. They are implemented as dynamic arrays allowing for efficient resizing and modifications. While         tuples are implemented as fixed size arrays. Their immutability offers sevral advantages.
#
# Q.7 What is the difference between "==" and "is" operators in python ?
# ANS: In Python, the == and is operators are both used for comparison, but they serve different purposes:
#      == (Equality Operator)
#      Purpose: Compares the values of two objects to check if they are equal.
#      Behavior: Evaluates to True if the values of the objects are the same, regardless of whether they are stored at the same memory location.
#
#      is (Identity Operator)
#      Purpose: Checks if two variables refer to the same object in memory.
#      Behavior: Evaluates to True if both variables point to the exact same object in memory.
#
# Q.8 What are logical operators in Python ?
# ANS: In Python, logical operators are used to combine conditional statements and evaluate expressions that result in Boolean values (True or False).        These operators are essential for controlling the flow of a program based on multiple conditions.
#
# Q.9 What is type casting in Python ?
# ANS: In Python, type casting refers to the process of converting a variable from one data type to another. This is          essential when performing       operations that require operands of the same type or when you need to ensure compatibility between different data types.
#
# Q.10 What is the difference between implicit and explicit type casting ?
# ANS: In Python, type casting refers to converting a variable from one data type to another. This can be done in two ways: implicit and explicit type        casting.
#
#      Implicit Type Casting
#      Definition: Python automatically converts one data type to another without explicit instruction from the programmer.
#      When It Happens: Occurs when an operation involves different data types, and Python promotes the lower data type to the higher one to prevent          data loss.
#
#      Explicit Type Casting
#      Definition: The programmer manually converts a value from one data type to another using built-in functions.
#
# Q.11 What is the purpose of conditional statements in Python ?
# ANS: In Python, conditional statements—such as if, elif, and else—are fundamental for controlling the flow of a program based on specific conditions.       They enable your program to make decisions and execute different blocks of code depending on whether certain conditions evaluate to True or False.
#
# Q.12 How does the elif statement work ?
# ANS: In Python, the elif statement—short for "else if"—is used to evaluate multiple conditions sequentially after an initial if statement. It allows        for more than two possible outcomes, making your code more readable and efficient by avoiding nested if statements.
#
# Q.13 What is the difference between for and while loops ?
# ANS: In Python, both for and while loops are used to execute a block of code repeatedly, but they differ in their structure and use cases. Here's a         detailed comparison:
#
#     for Loop
#     Purpose: Ideal for iterating over a sequence (like a list, tuple, or string) or a range of numbers.
#     Structure: Combines initialization, condition checking, and iteration in a single line.
#
#      while Loop
#      Purpose: Repeats a block of code as long as a specified condition is True.
#      Structure: Requires explicit initialization and manual updating of the loop variable.
#
# Q.14 Describe a scenario where a while loop is more suitable than a for loop ?
# ANS:
